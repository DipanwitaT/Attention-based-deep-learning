# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

data = pd.read_csv('attention_weights_normal.csv')
x=data.x
y=data.y

# %%
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams.update({'font.size': 12})
plt.plot(x, y)
plt.xlabel('No. of Features')
plt.ylabel('Attention Weights')
plt.savefig('C:/Users/Dipanwita/OneDrive/Desktop/Attentionwalk.eps', dpi=300, bbox_inches='tight')

# %%
import pandas as pd

data = pd.read_csv('attention_weights_hemiplegic.csv')
x1=data.x
y1=data.y

# %%
import matplotlib as mpl
import matplotlib.pylab as plt
from matplotlib.ticker import FormatStrFormatter
import matplotlib.ticker as mtick

# %%
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams.update({'font.size': 12})
fig, ax = plt.subplots()

ax.plot(x,y)

ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.3f'))
plt.xlabel('No. of Features')
plt.ylabel('Attention Weights')
plt.savefig('C:/Users/Dipanwita/OneDrive/Desktop/Attentiongait.eps', dpi=300, bbox_inches='tight')
plt.show()
